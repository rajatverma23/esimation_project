# %%
# !pip install mne-features
# Out:
# Collecting mne-features
#   Downloading mne_features-0.3-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mne-features) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mne-features) (1.11.4)
# Requirement already satisfied: numba in /opt/conda/lib/python3.10/site-packages (from mne-features) (0.58.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from mne-features) (1.2.2)
# Requirement already satisfied: mne in /opt/conda/lib/python3.10/site-packages (from mne-features) (1.6.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from mne-features) (1.5.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from mne-features) (2.2.2)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (3.7.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (4.66.1)
# Requirement already satisfied: pooch>=1.5 in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (1.8.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (5.1.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (21.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from mne->mne-features) (0.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba->mne-features) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->mne-features) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->mne-features) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->mne-features) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mne-features) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->mne-features) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->mne->mne-features) (3.1.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne->mne-features) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.5->mne->mne-features) (2.31.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->mne-features) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->mne->mne-features) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne-features) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne-features) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne-features) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.5->mne->mne-features) (2024.2.2)
# Downloading mne_features-0.3-py3-none-any.whl (26 kB)
# Installing collected packages: mne-features
# Successfully installed mne-features-0.3

# %%
# importing libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np
import os
import math

from mne_features.univariate import compute_higuchi_fd

# %%
# importing elpileptic and healthy data
def load_csv_files(directory):
    all_df = []    
    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            all_df.append(df)
    
    combined_df = pd.concat(all_df, ignore_index=True)   
    return combined_df

epi_directory = '/kaggle/input/epileptic'
healthy_directory = '/kaggle/input/healthy'

# loading epileptical data 
epi_data = load_csv_files(epi_directory)
# loading healthy data
heal_data = load_csv_files(healthy_directory)

# %%
# converting the dataframe into 2-D numpy-array
epi_data = np.asarray(epi_data.T)
heal_data = np.asarray(heal_data.T)
# adjusting sizes
# epi_resample_data = np.zeros_like(heal_data)
# for i in np.arange(0, 19):
#     epi_resample_data[i] = epi_data[i][ : 1207161]

# %%
epi_data.shape, heal_data.shape
# Out:
# ((19, 1844925), (19, 1207161))

# %% [markdown]
# ### fifth feautre : Higuchi Fractal Dimension

# %%
def compute_higuchi_fractical_dimension(eeg_data):
    # Compute the singular value decomposition and capturing the singular values
    higuchi_fractical_dimension_feautre = compute_higuchi_fd(eeg_data)
    return higuchi_fractical_dimension_feautre

# %%
# calculating the feautre of epi and healthy data
higuchi_fractical_dimension_epi_feautre = compute_higuchi_fractical_dimension(epi_data)
higuchi_fractical_dimension_heal_feautre = compute_higuchi_fractical_dimension(heal_data)

# %%
he_obs = higuchi_fractical_dimension_epi_feautre
epi_obs = higuchi_fractical_dimension_heal_feautre

mean_he_obs = np.mean(he_obs)
mean_epi_obs = np.std(epi_obs)

s_d_he_obs = np.mean(he_obs)
s_d_epi_obs = np.std(epi_obs)

# %%
# taking the log of the pdfs of epi and heal
p_h0_log =  np.log(1/np.sqrt(2*np.pi*s_d_he_obs)) + (-0.5*((he_obs - mean_he_obs)/s_d_he_obs)**2)
p_h1_log =  np.log(1/np.sqrt(2*np.pi*s_d_epi_obs)) + (-0.5*((epi_obs - mean_epi_obs - 20e-7)/s_d_epi_obs)**2)

# taking log LRT
ln_lrt = p_h1_log - p_h0_log

# %%
plt.plot(he_obs, p_h0_log, label = 'healthy')
plt.plot(epi_obs, p_h1_log, label = 'epileptical')
plt.legend()
plt.title('Probability Distribution Function of healthy vs epileptical')
# Out:
# Text(0.5, 1.0, 'Probability Distribution Function of healthy vs epileptical')

# %%
# finding the threshold
thresh = np.median(ln_lrt)

# finding lrt of heal (h0) and epi(h1)
lrt_h1 = []
lrt_h0 = []
for i in ln_lrt:
    if i > thresh:
        lrt_h1.append(i)
    else : 
        lrt_h0.append(i)

# %%
obs=(lrt_h1)
mean=np.mean(lrt_h1)
sigma=np.std(lrt_h1)

p_lrt_h1=(1/np.sqrt(2*np.pi*sigma))*np.exp(-0.5*((obs-mean)/sigma)**2)

obs=(lrt_h0)
mean=np.mean(lrt_h0)
sigma=np.std(lrt_h0)

p_lrt_h0=(1/np.sqrt(2*np.pi*sigma))*np.exp(-0.5*((obs-mean)/sigma)**2)

plt.plot(np.sort(lrt_h1), p_lrt_h1)
plt.plot(np.sort(lrt_h0), p_lrt_h0)

# %%
# plotting ROC curve
obs = (lrt_h1)
mean_pd = np.mean(lrt_h1)
sigma_pd = np.std(lrt_h1)

obs = (lrt_h0)
mean_pfa = np.mean(lrt_h0)
sigma_pfa = np.std(lrt_h0)

threshold=np.arange(-20* abs(max(lrt_h0)),20*np.abs(max(lrt_h0)), 2*np.abs(max(lrt_h0))/len(lrt_h0))
 
p_fa=[]
p_d=[]

for i in threshold:
    prob_false_alarm = 1 - norm.cdf(i, mean_pfa, sigma_pfa)
    p_fa.append(prob_false_alarm)
        
    prob_det = 1 - norm.cdf(i, mean_pd, sigma_pd)
    p_d.append(prob_det)

plt.plot(p_fa, p_d)
plt.xlabel("False Alarm Probability")
plt.ylabel("Detection Probability")
plt.title("ROC curve")
plt.tight_layout()
plt.show()

# %%
def auc_from_pfa_pd(pfa, pd):
    # Sort (PFA, PD) pairs by increasing PFA
    sorted_indices = np.argsort(pfa)
    sorted_pfa = np.array(pfa)[sorted_indices]
    sorted_pd = np.array(pd)[sorted_indices]
    # Interpolate the ROC curve
    roc_curve = np.trapz(sorted_pd, sorted_pfa)
    return roc_curve

# Calculate AUC
auc = auc_from_pfa_pd(p_fa, p_d)
print("AUC:", auc)
# Out:
# AUC: 0.9057166868498294
